# %% [markdown]
# ## Exploration des données

# %%
import os
import pandas as pd
from datetime import date, timedelta

df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-05-2020.csv', sep=',')
df.head(10)
# Out:
#   Province/State  Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2020-03-05T14:53:03      67466    2902
# 1            NaN     South Korea  2020-03-05T09:03:09       6088      35
# 2            NaN           Italy  2020-03-05T17:43:03       3858     148
# 3            NaN            Iran  2020-03-05T13:43:04       3513     107
# 4      Guangdong  Mainland China  2020-03-05T09:23:03       1351       7
# 5          Henan  Mainland China  2020-03-05T01:48:26       1272      22
# 6       Zhejiang  Mainland China  2020-03-05T09:43:03       1215       1
# 7          Hunan  Mainland China  2020-03-05T08:43:03       1018       4
# 8          Anhui  Mainland China  2020-03-05T04:33:02        990       6
# 9        Jiangxi  Mainland China  2020-03-05T01:16:58        935       1
#
#    Recovered  Latitude  Longitude
# 0      40592   30.9756   112.2707
# 1         41   36.0000   128.0000
# 2        414   43.0000    12.0000
# 3        739   32.0000    53.0000
# 4       1181   23.3417   113.4244
# 5       1239   33.8820   113.6140
# 6       1124   29.1832   120.0934
# 7        938   27.6104   111.7088
# 8        970   31.8257   117.2264
# 9        901   27.6140   115.7221

# %%
BASE_URL = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/'

# %% [markdown]
# ### Boucle de récupération des fichiers

# %%
from datetime import date, timedelta
sdate = date(2020, 1, 22)
edate = date(2020, 3, 5)
delta = edate - sdate

# %%
RAWFILES_DIR = '../data/raw'

for i in range(delta.days + 1):
    day=sdate + timedelta(days=i)
    day_label = day.strftime("%m-%d-%Y") + '.csv'
    virus_df=pd.read_csv(BASE_URL + day_label, sep=',')
    virus_df.to_csv(os.path.join(RAWFILES_DIR, day_label), index=False)

# %%
# Method2
BASE_URL = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{}.csv'

# %%
for i in range(delta.days + 1):
    day=sdate + timedelta(days=i)
    day_label = day.strftime("%m-%d-%Y")
    virus_df=pd.read_csv(BASE_URL.format(day_label), sep=',')
    virus_df.to_csv(os.path.join(RAWFILES_DIR, day_label+'.csv'), index=False)

# %% [markdown]
# ## Constitution de la table de références lat/log

# %%
import glob
RAWFILES_DIR = '../data/raw'

df_list = []
for file in glob.glob(os.path.join(RAWFILES_DIR,'*csv')):
    virus_df=pd.read_csv(file, sep=',')
    if 'Latitude' in virus_df.columns and 'Longitude' in virus_df.columns:
        df_list.append(virus_df)
all_df = pd.concat(df_list)
all_df.shape
# Out:
# (750, 8)

# %%
RAWFILES_DIR = '../data/processed'

# %%
(all_df[['Province/State','Country/Region','Latitude','Longitude']
       ].drop_duplicates(subset=['Province/State','Country/Region']
                        ).sort_values(['Province/State','Country/Region']
                                     ).to_csv(os.path.join(RAWFILES_DIR,'lon_lag.csv'
                                                          ), index=False))

# %%
lon_lag = pd.read_csv(os.path.join(RAWFILES_DIR,'lon_lag.csv'))
df_list = []
for file in glob.glob(os.path.join(RAWFILES_DIR,'*csv')):
    virus_df=pd.read_csv(file, sep=',')
    if not ('Latitude' in virus_df.columns and 'Longitude' in virus_df.columns):
        virus_df = virus_df.merge(lon_lag, on=['Province/State','Country/Region'], how='left')
    
    df_list.append(virus_df.assign(source=os.path.basename(file))) # add a source columns in the table
        
all_df = pd.concat(df_list)
all_df
# Out:
#           Province/State        Country/Region  Latitude  Longitude  \
# 0           Montreal, QC                Canada   45.5017   -73.5673
# 1     Norfolk County, MA                    US   42.1767   -71.1449
# 2                  Anhui        Mainland China   31.8257   117.2264
# 3                Beijing        Mainland China   40.1824   116.4142
# 4      Bergen County, NJ                    US   40.9263   -74.0770
# ..                   ...                   ...       ...        ...
# 172                  NaN               Tunisia   34.0000     9.0000
# 173                  NaN                    UK   55.0000    -3.0000
# 174                  NaN               Ukraine   48.3794    31.1656
# 175                  NaN  United Arab Emirates   24.0000    54.0000
# 176                  NaN               Vietnam   16.0000   108.0000
#
#           source
# 0    lon_lag.csv
# 1    lon_lag.csv
# 2    lon_lag.csv
# 3    lon_lag.csv
# 4    lon_lag.csv
# ..           ...
# 172  lon_lag.csv
# 173  lon_lag.csv
# 174  lon_lag.csv
# 175  lon_lag.csv
# 176  lon_lag.csv
#
# [177 rows x 5 columns]
